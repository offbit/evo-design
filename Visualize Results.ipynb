# %%
import cPickle
import numpy as np
import pylab as pl
# %matplotlib inline 
import seaborn as sns
import pandas as pd

# %%
stats = cPickle.load(open('tourney_9.stats', 'rb'))
print len(stats[0])
stats = np.array(stats)

x = []
y = []
mu = []
print(stats.shape)
for e in range(stats.shape[0]):
    x += [e] * stats.shape[1]
    y += list(stats[e])
    mu.append(np.mean(y))
data = pd.DataFrame({'epoch':x, 'accuracy':y})
# Out:
# 50
# (10, 50)

# %%
mus = pd.DataFrame({'epoch':np.arange(stats.shape[0]), 'accuracy':mu})
print(mus)
# Out:
#     accuracy  epoch
# 0  62.125000      0
# 1  66.972500      1
# 2  70.855267      2
# 3  70.024750      3
# 4  71.722440      4
# 5  73.432100      5
# 6  74.373800      6
# 7  75.568725      7
# 8  76.124644      8
# 9  77.281160      9

# %%
max_i = np.argmax(y)
x[max_i], y[max_i]
pl.figure(figsize=(8,8))
sns.boxplot(x="epoch", y="accuracy", data=data)
# sns.swarmplot(x="epoch", y="accuracy", data=data)
sns.stripplot(x="epoch", y="accuracy", data=mus, jitter=True, size=8, color=".1", linewidth=0)
# label = 'Max accuracy:{}%'.format(y[max_i])
# pl.plot([y[max_i]]*10, label=label)
pl.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

print(y[max_i])
# Out:
# /home/stathis/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# 92.84

# %%
sns.distplot(y, bins=20, kde=False, rug=False)

# %%
max_i = np.argmax(y)
x[max_i], y[max_i]
pl.figure(figsize=(8,8))
# sns.boxplot(x="epoch", y="accuracy", data=data)
sns.swarmplot(x="epoch", y="accuracy", data=data)
sns.stripplot(x="epoch", y="accuracy", data=mus, jitter=True, size=8, color=".1", linewidth=0)
label = 'Max accuracy:{}%'.format(y[max_i])
pl.plot([y[max_i]]*10, label=label)
pl.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

print(y[max_i])
# Out:
# 93.59

# %%
# !ls
# Out:
# data				  sync.sh
# envs.py				  tournament.population_history
# evo_cma.py			  tournament.stats
# evo_es.py			  tourney_50_top3.stats
# evo_snes.py			  tourney_top3_20.stats
# experiment.py			  tourney_top3_20.stats.png
# model_factory			  tourney_top3_50_2_optimizers.stats.png
# optim				  tourney_top3_50_2.stats.png
# Random_50_2_optimizers.stats.png  tourney_top3_50.stats.png
# Random_50.stats.png		  tourney_top5_20.stats.png
# README.md			  Visualize Results.ipynb
